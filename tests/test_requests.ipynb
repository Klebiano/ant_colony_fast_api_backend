# %%
import requests
from dotenv import load_dotenv
import os
import urllib
import json
from pathlib import Path
import aiohttp
import asyncio
import pandas as pd
from sqlalchemy import create_engine
from IPython.display import display, HTML

# %%
async def fetch(session, url):
    headers = {
        'Accept': 'application/json, text/plain, */*',
        'Accept-Language': 'pt-BR,pt;q=0.9,en;q=0.8,en-GB;q=0.7,en-US;q=0.6',
        'Connection': 'keep-alive',
        'Content-Type': 'application/json',
        'Origin': 'http://127.0.0.1:5173',
        'Referer': 'http://127.0.0.1:5173/',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-site',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/117.0.0.0 Safari/537.36 Edg/117.0.2045.47',
        'sec-ch-ua': '"Microsoft Edge";v="117", "Not;A=Brand";v="8", "Chromium";v="117"',
        'sec-ch-ua-mobile': '?0',
        'sec-ch-ua-platform': '"Windows"',
    }

    json_data = [
        {
            'turbine_id': 93,
            'turbine_name': 'BETA-92',
            'subsystem_name': 'Sensors',
            'fault_type': 'Minor',
        },
    ]
    async with session.post(url, 
                            headers=headers, json=json_data) as response:
        return await response.text()

# %%
async def main():
    tasks = []
    async with aiohttp.ClientSession() as session:
        for iter in range(1, 3):
            tasks.append(fetch(session, 'http://127.0.0.1:8000/ant-colony/run-ant-colony-path/'))
        results = await asyncio.gather(*tasks)
    return results

# %%
# if __name__ == '__main__':
# loop = asyncio.get_event_loop()
# loop.run_until_complete(main())
results = await main()

# %%
results
# Out:
# '{"turbine_order":["Doca","BETA-01","BETA-33","BETA-205","BETA-40","BETA-55","BETA-52","BETA-182","BETA-184","BETA-153","BETA-118","BETA-120","BETA-123","BETA-126","BETA-145","BETA-138","BETA-137","BETA-45","BETA-62","BETA-84","BETA-89","BETA-85","BETA-65","BETA-74","BETA-69","BETA-20","BETA-82","BETA-149","BETA-135","BETA-141","BETA-174","BETA-158","BETA-161","BETA-212","BETA-172","BETA-198","BETA-09","BETA-30","BETA-25","BETA-18","BETA-05"],"best_path":[0,1,8,39,9,12,11,36,37,31,21,22,23,24,29,27,26,10,13,18,20,19,14,16,15,5,17,30,25,28,35,32,33,40,34,38,3,7,6,4,2,0],"best_path_length":8.305186266410871,"best_downtime_days":2.4793684965913125}'
